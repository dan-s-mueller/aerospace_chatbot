# %%
# Load environment variables
import os
import re
import pinecone
import glob
import data_import
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Pinecone
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders import UnstructuredPDFLoader, OnlinePDFLoader, PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from dotenv import load_dotenv,find_dotenv
load_dotenv(find_dotenv(),override=True)
# Out:
# True

# %%
# Check api keys
# print(os.getenv('OPENAI_API_KEY'))
# print(os.getenv('PINECONE_ENVIRONMENT'))
# print(os.getenv('PINECONE_API_KEY'))

# %%
# Instantiate OpenAI embeddings
embeddings_model = OpenAIEmbeddings(model="text-embedding-ada-002")

# %%
# Initialize Pinecone client, test if it works
# pinecone.init(
#     api_key=os.getenv('PINECONE_API_KEY'),
#     environment=os.getenv('PINECONE_ENVIRONMENT') 
# )
# pinecone.whoami()

# %%
# Find the existing index, clear for new start
# index=pinecone.Index(index_name)

# %%
# Pinecone database: https://app.pinecone.io/organizations/-Nam3zmbSmzuXKeH8EWl/projects/us-west1-gcp-free:32467cc/indexes/langchain-quickstart
index_name = "ams"

# data_folder='../data/FEA/'
data_folder='../data/AMS/'
docs = glob.glob(data_folder+'*.pdf')   # Only get the PDFs in the directory

data_import.load_docs(index_name=index_name,
                      embeddings_model=embeddings_model,
                      docs=docs,
                      PINECONE_API_KEY=os.getenv('PINECONE_API_KEY'),
                      PINECONE_ENVIRONMENT=os.getenv('PINECONE_ENVIRONMENT'),
                      chunk_size=5000,
                      chunk_overlap=0)
# Out:
# Cleared database.
# Parsing: ../data/AMS/AMS_2006.pdf
# Uploading to pinecone index langchain-quickstart
# Parsing: ../data/AMS/AMS_2012.pdf
# Uploading to pinecone index langchain-quickstart
# Parsing: ../data/AMS/AMS_2004.pdf
# Uploading to pinecone index langchain-quickstart
# Parsing: ../data/AMS/AMS_2010.pdf
# Uploading to pinecone index langchain-quickstart
# Parsing: ../data/AMS/AMS_2014.pdf
# Uploading to pinecone index langchain-quickstart
# Multiple definitions in dictionary at byte 0x13f4 for key /Length
# Multiple definitions in dictionary at byte 0x5ad9 for key /Length
# Multiple definitions in dictionary at byte 0x14a44 for key /Length
# Multiple definitions in dictionary at byte 0x16e26 for key /Length
# Multiple definitions in dictionary at byte 0x1a206 for key /Length
# Multiple definitions in dictionary at byte 0x25e23 for key /Length
# Multiple definitions in dictionary at byte 0x26aac for key /Length
# Multiple definitions in dictionary at byte 0x2fa1b for key /Length
# Multiple definitions in dictionary at byte 0x39302 for key /Length
# Multiple definitions in dictionary at byte 0x3bc83 for key /Length
# Multiple definitions in dictionary at byte 0x46ebc for key /Length
# Multiple definitions in dictionary at byte 0x522b8 for key /Length
# Multiple definitions in dictionary at byte 0x5d547 for key /Length
# Multiple definitions in dictionary at byte 0x64fc4 for key /Length
# Parsing: ../data/AMS/AMS_2000.pdf
# Multiple definitions in dictionary at byte 0x6b3f2 for key /Length
# Multiple definitions in dictionary at byte 0x7d939 for key /Length
# Multiple definitions in dictionary at byte 0x90a90 for key /Length
# Multiple definitions in dictionary at byte 0xa65da for key /Length
# Multiple definitions in dictionary at byte 0xbca8d for key /Length
# Multiple definitions in dictionary at byte 0xd3e06 for key /Length
# Multiple definitions in dictionary at byte 0xea20f for key /Length
# Multiple definitions in dictionary at byte 0xfeb82 for key /Length
# Multiple definitions in dictionary at byte 0x1156b5 for key /Length
# Multiple definitions in dictionary at byte 0x12a701 for key /Length
# Multiple definitions in dictionary at byte 0x1399f3 for key /Length
# Multiple definitions in dictionary at byte 0x14ae2e for key /Length
# Multiple definitions in dictionary at byte 0x1563fd for key /Length
# Multiple definitions in dictionary at byte 0x15b628 for key /Length
# Multiple definitions in dictionary at byte 0x1618b6 for key /Length
# Multiple definitions in dictionary at byte 0x1757be for key /Length
# Multiple definitions in dictionary at byte 0x187e9c for key /Length
# Multiple definitions in dictionary at byte 0x19c095 for key /Length
# Multiple definitions in dictionary at byte 0x1a7edd for key /Length
# Multiple definitions in dictionary at byte 0x1be2f2 for key /Length
# Multiple definitions in dictionary at byte 0x1d6839 for key /Length
# Multiple definitions in dictionary at byte 0x1eaa8f for key /Length
# Multiple definitions in dictionary at byte 0x1f7bbd for key /Length
# Multiple definitions in dictionary at byte 0x20fc02 for key /Length
# Multiple definitions in dictionary at byte 0x2269af for key /Length
# Multiple definitions in dictionary at byte 0x23d457 for key /Length
# Multiple definitions in dictionary at byte 0x2536ee for key /Length
# Multiple definitions in dictionary at byte 0x267f38 for key /Length
# Multiple definitions in dictionary at byte 0x27351e for key /Length
# Multiple definitions in dictionary at byte 0x2859d4 for key /Length
# Multiple definitions in dictionary at byte 0x293f7b for key /Length
# Multiple definitions in dictionary at byte 0x29f627 for key /Length
# Multiple definitions in dictionary at byte 0x2b6883 for key /Length
# Multiple definitions in dictionary at byte 0x2c7ca3 for key /Length
# Multiple definitions in dictionary at byte 0x2d93d5 for key /Length
# Multiple definitions in dictionary at byte 0x2ec93b for key /Length
# Multiple definitions in dictionary at byte 0x2f5121 for key /Length
# Multiple definitions in dictionary at byte 0x309425 for key /Length
# Multiple definitions in dictionary at byte 0x3195d5 for key /Length
# Multiple definitions in dictionary at byte 0x32862f for key /Length
# Multiple definitions in dictionary at byte 0x338adf for key /Length
# Multiple definitions in dictionary at byte 0x3450b5 for key /Length
# Multiple definitions in dictionary at byte 0x34fcd8 for key /Length
# Multiple definitions in dictionary at byte 0x35b437 for key /Length
# Multiple definitions in dictionary at byte 0x36eb21 for key /Length
# Multiple definitions in dictionary at byte 0x37cd10 for key /Length
# Multiple definitions in dictionary at byte 0x388e7e for key /Length
# Multiple definitions in dictionary at byte 0x395469 for key /Length
# Multiple definitions in dictionary at byte 0x39ed77 for key /Length
# Multiple definitions in dictionary at byte 0x3a786a for key /Length
# Multiple definitions in dictionary at byte 0x3b0137 for key /Length
# Multiple definitions in dictionary at byte 0x3c11d3 for key /Length
# Multiple definitions in dictionary at byte 0x3d42c9 for key /Length
# Multiple definitions in dictionary at byte 0x3e226e for key /Length
# Multiple definitions in dictionary at byte 0x3ec7f0 for key /Length
# Multiple definitions in dictionary at byte 0x3f76e5 for key /Length
# Multiple definitions in dictionary at byte 0x402624 for key /Length
# Multiple definitions in dictionary at byte 0x412947 for key /Length
# Multiple definitions in dictionary at byte 0x420e46 for key /Length
# Multiple definitions in dictionary at byte 0x42b2ac for key /Length
# Multiple definitions in dictionary at byte 0x435ab4 for key /Length
# Multiple definitions in dictionary at byte 0x443bc7 for key /Length
# Multiple definitions in dictionary at byte 0x453045 for key /Length
# Multiple definitions in dictionary at byte 0x46153c for key /Length
# Multiple definitions in dictionary at byte 0x46a7ff for key /Length
# Multiple definitions in dictionary at byte 0x47ca7a for key /Length
# Multiple definitions in dictionary at byte 0x48b73e for key /Length
# Multiple definitions in dictionary at byte 0x492fb6 for key /Length
# Multiple definitions in dictionary at byte 0x4a7143 for key /Length
# Multiple definitions in dictionary at byte 0x4b2a02 for key /Length
# Multiple definitions in dictionary at byte 0x4c5b38 for key /Length
# Multiple definitions in dictionary at byte 0x4d935a for key /Length
# Multiple definitions in dictionary at byte 0x4ea138 for key /Length
# Multiple definitions in dictionary at byte 0x4f73af for key /Length
# Multiple definitions in dictionary at byte 0x4f873c for key /Length
# Multiple definitions in dictionary at byte 0x50b747 for key /Length
# Multiple definitions in dictionary at byte 0x520065 for key /Length
# Multiple definitions in dictionary at byte 0x52d66f for key /Length
# Multiple definitions in dictionary at byte 0x537ad4 for key /Length
# Multiple definitions in dictionary at byte 0x5484cf for key /Length
# Multiple definitions in dictionary at byte 0x55c2ba for key /Length
# Multiple definitions in dictionary at byte 0x574fdd for key /Length
# Multiple definitions in dictionary at byte 0x585d5b for key /Length
# Multiple definitions in dictionary at byte 0x599b19 for key /Length
# Multiple definitions in dictionary at byte 0x5ae1c9 for key /Length
# Multiple definitions in dictionary at byte 0x5c294f for key /Length
# Multiple definitions in dictionary at byte 0x5db475 for key /Length
# Multiple definitions in dictionary at byte 0x5ea9c7 for key /Length
# Multiple definitions in dictionary at byte 0x5f9da4 for key /Length
# Multiple definitions in dictionary at byte 0x60c593 for key /Length
# Multiple definitions in dictionary at byte 0x622753 for key /Length
# Multiple definitions in dictionary at byte 0x6385f0 for key /Length
# Multiple definitions in dictionary at byte 0x648727 for key /Length
# Multiple definitions in dictionary at byte 0x65d47b for key /Length
# Multiple definitions in dictionary at byte 0x66cc6f for key /Length
# Multiple definitions in dictionary at byte 0x67cd1b for key /Length
# Multiple definitions in dictionary at byte 0x68f885 for key /Length
# Multiple definitions in dictionary at byte 0x698567 for key /Length
# Multiple definitions in dictionary at byte 0x6a5fc0 for key /Length
# Multiple definitions in dictionary at byte 0x6bb5d9 for key /Length
# Multiple definitions in dictionary at byte 0x6c74df for key /Length
# Multiple definitions in dictionary at byte 0x6d60b4 for key /Length
# Multiple definitions in dictionary at byte 0x6e60ca for key /Length
# Multiple definitions in dictionary at byte 0x6f2cf2 for key /Length
# Multiple definitions in dictionary at byte 0x6fd725 for key /Length
# Multiple definitions in dictionary at byte 0x70e39c for key /Length
# Multiple definitions in dictionary at byte 0x720f0d for key /Length
# Multiple definitions in dictionary at byte 0x72eec0 for key /Length
# Multiple definitions in dictionary at byte 0x73d622 for key /Length
# Multiple definitions in dictionary at byte 0x74d958 for key /Length
# Multiple definitions in dictionary at byte 0x760a5e for key /Length
# Multiple definitions in dictionary at byte 0x77276e for key /Length
# Multiple definitions in dictionary at byte 0x78346d for key /Length
# Multiple definitions in dictionary at byte 0x78b8d1 for key /Length
# Multiple definitions in dictionary at byte 0x797a42 for key /Length
# Multiple definitions in dictionary at byte 0x7a38a9 for key /Length
# Multiple definitions in dictionary at byte 0x7aecfa for key /Length
# Multiple definitions in dictionary at byte 0x7c41eb for key /Length
# Multiple definitions in dictionary at byte 0x7d99a1 for key /Length
# Multiple definitions in dictionary at byte 0x7ee8d3 for key /Length
# Multiple definitions in dictionary at byte 0x80267d for key /Length
# Multiple definitions in dictionary at byte 0x8179a0 for key /Length
# Multiple definitions in dictionary at byte 0x826f1c for key /Length
# Multiple definitions in dictionary at byte 0x838d27 for key /Length
# Multiple definitions in dictionary at byte 0x84e742 for key /Length
# Multiple definitions in dictionary at byte 0x85fd1f for key /Length
# Multiple definitions in dictionary at byte 0x8769a0 for key /Length
# Multiple definitions in dictionary at byte 0x887c69 for key /Length
# Multiple definitions in dictionary at byte 0x89dbce for key /Length
# Multiple definitions in dictionary at byte 0x8ae9ae for key /Length
# Multiple definitions in dictionary at byte 0x8b9d05 for key /Length
# Multiple definitions in dictionary at byte 0x8ca8a1 for key /Length
# Multiple definitions in dictionary at byte 0x8dbe1f for key /Length
# Multiple definitions in dictionary at byte 0x8ec9dd for key /Length
# Multiple definitions in dictionary at byte 0x8f7202 for key /Length
# Multiple definitions in dictionary at byte 0x8ff852 for key /Length
# Multiple definitions in dictionary at byte 0x9094fe for key /Length
# Multiple definitions in dictionary at byte 0x917ced for key /Length
# Multiple definitions in dictionary at byte 0x923a38 for key /Length
# Multiple definitions in dictionary at byte 0x930433 for key /Length
# Multiple definitions in dictionary at byte 0x94513d for key /Length
# Multiple definitions in dictionary at byte 0x9558e3 for key /Length
# Multiple definitions in dictionary at byte 0x9623d3 for key /Length
# Multiple definitions in dictionary at byte 0x97552b for key /Length
# Multiple definitions in dictionary at byte 0x97f151 for key /Length
# Multiple definitions in dictionary at byte 0x98c360 for key /Length
# Multiple definitions in dictionary at byte 0x997097 for key /Length
# Multiple definitions in dictionary at byte 0x9a2e24 for key /Length
# Multiple definitions in dictionary at byte 0x9ba195 for key /Length
# Multiple definitions in dictionary at byte 0x9c3798 for key /Length
# Multiple definitions in dictionary at byte 0x9c49a2 for key /Length
# Multiple definitions in dictionary at byte 0x9d5f42 for key /Length
# Multiple definitions in dictionary at byte 0x9e7f21 for key /Length
# Multiple definitions in dictionary at byte 0x9f754f for key /Length
# Multiple definitions in dictionary at byte 0xa0434b for key /Length
# Multiple definitions in dictionary at byte 0xa190a3 for key /Length
# Multiple definitions in dictionary at byte 0xa1a257 for key /Length
# Multiple definitions in dictionary at byte 0xa2c8db for key /Length
# Multiple definitions in dictionary at byte 0xa3ae34 for key /Length
# Multiple definitions in dictionary at byte 0xa48485 for key /Length
# Multiple definitions in dictionary at byte 0xa5243f for key /Length
# Multiple definitions in dictionary at byte 0xa64da9 for key /Length
# Multiple definitions in dictionary at byte 0xa7473e for key /Length
# Multiple definitions in dictionary at byte 0xa82003 for key /Length
# Multiple definitions in dictionary at byte 0xa97b47 for key /Length
# Multiple definitions in dictionary at byte 0xaa77e8 for key /Length
# Multiple definitions in dictionary at byte 0xab3d31 for key /Length
# Multiple definitions in dictionary at byte 0xac226c for key /Length
# Multiple definitions in dictionary at byte 0xad113d for key /Length
# Multiple definitions in dictionary at byte 0xaeaa53 for key /Length
# Multiple definitions in dictionary at byte 0xafdb7d for key /Length
# Multiple definitions in dictionary at byte 0xb110a7 for key /Length
# Multiple definitions in dictionary at byte 0xb267f6 for key /Length
# Multiple definitions in dictionary at byte 0xb3afb3 for key /Length
# Multiple definitions in dictionary at byte 0xb4a47a for key /Length
# Multiple definitions in dictionary at byte 0xb57884 for key /Length
# Multiple definitions in dictionary at byte 0xb68afd for key /Length
# Multiple definitions in dictionary at byte 0xb76831 for key /Length
# Multiple definitions in dictionary at byte 0xb821de for key /Length
# Multiple definitions in dictionary at byte 0xb912ec for key /Length
# Multiple definitions in dictionary at byte 0xb9dca7 for key /Length
# Multiple definitions in dictionary at byte 0xba3d68 for key /Length
# Multiple definitions in dictionary at byte 0xbb7174 for key /Length
# Multiple definitions in dictionary at byte 0xbc3539 for key /Length
# Multiple definitions in dictionary at byte 0xbd31fa for key /Length
# Multiple definitions in dictionary at byte 0xbe18fe for key /Length
# Multiple definitions in dictionary at byte 0xbf482d for key /Length
# Multiple definitions in dictionary at byte 0xc06b24 for key /Length
# Multiple definitions in dictionary at byte 0xc12c19 for key /Length
# Multiple definitions in dictionary at byte 0xc1f2f3 for key /Length
# Multiple definitions in dictionary at byte 0xc2f87e for key /Length
# Multiple definitions in dictionary at byte 0xc42288 for key /Length
# Multiple definitions in dictionary at byte 0xc52c09 for key /Length
# Multiple definitions in dictionary at byte 0xc5e331 for key /Length
# Multiple definitions in dictionary at byte 0xc6df45 for key /Length
# Multiple definitions in dictionary at byte 0xc7a6d9 for key /Length
# Multiple definitions in dictionary at byte 0xc81e2a for key /Length
# Multiple definitions in dictionary at byte 0xc85883 for key /Length
# Multiple definitions in dictionary at byte 0xc8d2ab for key /Length
# Multiple definitions in dictionary at byte 0xc9e5e2 for key /Length
# Multiple definitions in dictionary at byte 0xcb787d for key /Length
# Multiple definitions in dictionary at byte 0xcce0d9 for key /Length
# Multiple definitions in dictionary at byte 0xce3ccb for key /Length
# Multiple definitions in dictionary at byte 0xcfabd0 for key /Length
# Multiple definitions in dictionary at byte 0xd0fe41 for key /Length
# Multiple definitions in dictionary at byte 0xd1624f for key /Length
# Multiple definitions in dictionary at byte 0xd28848 for key /Length
# Multiple definitions in dictionary at byte 0xd39cf9 for key /Length
# Multiple definitions in dictionary at byte 0xd474b6 for key /Length
# Multiple definitions in dictionary at byte 0xd5c1c9 for key /Length
# Multiple definitions in dictionary at byte 0xd65de8 for key /Length
# Multiple definitions in dictionary at byte 0xd7f124 for key /Length
# Multiple definitions in dictionary at byte 0xd9104c for key /Length
# Multiple definitions in dictionary at byte 0xd9cc3f for key /Length
# Multiple definitions in dictionary at byte 0xdb21b9 for key /Length
# Multiple definitions in dictionary at byte 0xdc1a50 for key /Length
# Multiple definitions in dictionary at byte 0xdd11b5 for key /Length
# Multiple definitions in dictionary at byte 0xde6335 for key /Length
# Multiple definitions in dictionary at byte 0xdfbbc4 for key /Length
# Multiple definitions in dictionary at byte 0xe12883 for key /Length
# Multiple definitions in dictionary at byte 0xe285e1 for key /Length
# Multiple definitions in dictionary at byte 0xe39317 for key /Length
# Multiple definitions in dictionary at byte 0xe4b455 for key /Length
# Multiple definitions in dictionary at byte 0xe56a73 for key /Length
# Multiple definitions in dictionary at byte 0xe57d7a for key /Length
# Multiple definitions in dictionary at byte 0xe632a4 for key /Length
# Multiple definitions in dictionary at byte 0xe6c49d for key /Length
# Multiple definitions in dictionary at byte 0xe79c6e for key /Length
# Multiple definitions in dictionary at byte 0xe80d1f for key /Length
# Multiple definitions in dictionary at byte 0xe89fa8 for key /Length
# Multiple definitions in dictionary at byte 0xe98ec7 for key /Length
# Multiple definitions in dictionary at byte 0xeaa766 for key /Length
# Multiple definitions in dictionary at byte 0xebca32 for key /Length
# Multiple definitions in dictionary at byte 0xed05f0 for key /Length
# Multiple definitions in dictionary at byte 0xedb516 for key /Length
# Multiple definitions in dictionary at byte 0xee3dd7 for key /Length
# Multiple definitions in dictionary at byte 0xef1710 for key /Length
# Multiple definitions in dictionary at byte 0xefeb09 for key /Length
# Multiple definitions in dictionary at byte 0xf08ac1 for key /Length
# Multiple definitions in dictionary at byte 0xf15ac6 for key /Length
# Multiple definitions in dictionary at byte 0xf25d27 for key /Length
# Multiple definitions in dictionary at byte 0xf2c0c9 for key /Length
# Multiple definitions in dictionary at byte 0xf3e1e5 for key /Length
# Multiple definitions in dictionary at byte 0xf47a66 for key /Length
# Multiple definitions in dictionary at byte 0xf5672e for key /Length
# Multiple definitions in dictionary at byte 0xf6704a for key /Length
# Multiple definitions in dictionary at byte 0xf7451d for key /Length
# Multiple definitions in dictionary at byte 0xf7d1e0 for key /Length
# Multiple definitions in dictionary at byte 0xf8c308 for key /Length
# Multiple definitions in dictionary at byte 0xf99e97 for key /Length
# Multiple definitions in dictionary at byte 0xf9b62f for key /Length
# Multiple definitions in dictionary at byte 0xfac270 for key /Length
# Multiple definitions in dictionary at byte 0xfbd757 for key /Length
# Multiple definitions in dictionary at byte 0xfcda9a for key /Length
# Multiple definitions in dictionary at byte 0xfdbf31 for key /Length
# Multiple definitions in dictionary at byte 0xfedf19 for key /Length
# Multiple definitions in dictionary at byte 0x100244a for key /Length
# Multiple definitions in dictionary at byte 0x1014402 for key /Length
# Multiple definitions in dictionary at byte 0x1023947 for key /Length
# Multiple definitions in dictionary at byte 0x1037e2e for key /Length
# Multiple definitions in dictionary at byte 0x1046735 for key /Length
# Multiple definitions in dictionary at byte 0x1059ed1 for key /Length
# Multiple definitions in dictionary at byte 0x1062771 for key /Length
# Multiple definitions in dictionary at byte 0x106e7fd for key /Length
# Multiple definitions in dictionary at byte 0x106f6c7 for key /Length
# Multiple definitions in dictionary at byte 0x107e4e1 for key /Length
# Multiple definitions in dictionary at byte 0x108a499 for key /Length
# Multiple definitions in dictionary at byte 0x109ad7d for key /Length
# Multiple definitions in dictionary at byte 0x10a3225 for key /Length
# Multiple definitions in dictionary at byte 0x10b9c4f for key /Length
# Multiple definitions in dictionary at byte 0x10c9281 for key /Length
# Multiple definitions in dictionary at byte 0x10d3c24 for key /Length
# Multiple definitions in dictionary at byte 0x10e1f8e for key /Length
# Multiple definitions in dictionary at byte 0x10f1231 for key /Length
# Multiple definitions in dictionary at byte 0x1102992 for key /Length
# Multiple definitions in dictionary at byte 0x11115bf for key /Length
# Multiple definitions in dictionary at byte 0x1120491 for key /Length
# Multiple definitions in dictionary at byte 0x112dccc for key /Length
# Multiple definitions in dictionary at byte 0x113f5ce for key /Length
# Multiple definitions in dictionary at byte 0x1156976 for key /Length
# Multiple definitions in dictionary at byte 0x116759f for key /Length
# Multiple definitions in dictionary at byte 0x117edbd for key /Length
# Multiple definitions in dictionary at byte 0x1194b66 for key /Length
# Multiple definitions in dictionary at byte 0x11a5de5 for key /Length
# Multiple definitions in dictionary at byte 0x11b17e6 for key /Length
# Multiple definitions in dictionary at byte 0x11c4042 for key /Length
# Multiple definitions in dictionary at byte 0x11c6ee8 for key /Length
# Multiple definitions in dictionary at byte 0x11d9396 for key /Length
# Multiple definitions in dictionary at byte 0x11e7184 for key /Length
# Multiple definitions in dictionary at byte 0x11f9284 for key /Length
# Multiple definitions in dictionary at byte 0x1206755 for key /Length
# Multiple definitions in dictionary at byte 0x1218f4a for key /Length
# Multiple definitions in dictionary at byte 0x122b813 for key /Length
# Multiple definitions in dictionary at byte 0x1238a3b for key /Length
# Multiple definitions in dictionary at byte 0x12447d2 for key /Length
# Multiple definitions in dictionary at byte 0x1252057 for key /Length
# Multiple definitions in dictionary at byte 0x125fdde for key /Length
# Multiple definitions in dictionary at byte 0x1271b9a for key /Length
# Multiple definitions in dictionary at byte 0x127bb55 for key /Length
# Multiple definitions in dictionary at byte 0x128ce16 for key /Length
# Multiple definitions in dictionary at byte 0x1299bbd for key /Length
# Multiple definitions in dictionary at byte 0x12a9b11 for key /Length
# Multiple definitions in dictionary at byte 0x12aace6 for key /Length
# Multiple definitions in dictionary at byte 0x12bcb51 for key /Length
# Multiple definitions in dictionary at byte 0x12cbc21 for key /Length
# Multiple definitions in dictionary at byte 0x12da2fa for key /Length
# Multiple definitions in dictionary at byte 0x12e170c for key /Length
# Multiple definitions in dictionary at byte 0x13028ef for key /Length
# Multiple definitions in dictionary at byte 0x1316de5 for key /Length
# Multiple definitions in dictionary at byte 0x132f20f for key /Length
# Multiple definitions in dictionary at byte 0x133dc85 for key /Length
# Multiple definitions in dictionary at byte 0x134f88e for key /Length
# Multiple definitions in dictionary at byte 0x135a009 for key /Length
# Multiple definitions in dictionary at byte 0x1365ffe for key /Length
# Multiple definitions in dictionary at byte 0x136a171 for key /Length
# Multiple definitions in dictionary at byte 0x137803f for key /Length
# Multiple definitions in dictionary at byte 0x13870a8 for key /Length
# Multiple definitions in dictionary at byte 0x139abf1 for key /Length
# Multiple definitions in dictionary at byte 0x13abc67 for key /Length
# Multiple definitions in dictionary at byte 0x13bbab3 for key /Length
# Multiple definitions in dictionary at byte 0x13caf7a for key /Length
# Multiple definitions in dictionary at byte 0x13d663f for key /Length
# Multiple definitions in dictionary at byte 0x13dca8f for key /Length
# Multiple definitions in dictionary at byte 0x13eae05 for key /Length
# Multiple definitions in dictionary at byte 0x13f9b63 for key /Length
# Multiple definitions in dictionary at byte 0x1408392 for key /Length
# Multiple definitions in dictionary at byte 0x1419e17 for key /Length
# Multiple definitions in dictionary at byte 0x1427a98 for key /Length
# Multiple definitions in dictionary at byte 0x143b387 for key /Length
# Multiple definitions in dictionary at byte 0x1440b58 for key /Length
# Multiple definitions in dictionary at byte 0x1453fe0 for key /Length
# Multiple definitions in dictionary at byte 0x1465f9d for key /Length
# Multiple definitions in dictionary at byte 0x1477d0c for key /Length
# Multiple definitions in dictionary at byte 0x1495c7c for key /Length
# Multiple definitions in dictionary at byte 0x14a509f for key /Length
# Multiple definitions in dictionary at byte 0x14b8e98 for key /Length
# Multiple definitions in dictionary at byte 0x14cb473 for key /Length
# Multiple definitions in dictionary at byte 0x14e248f for key /Length
# Multiple definitions in dictionary at byte 0x14ed706 for key /Length
# Multiple definitions in dictionary at byte 0x14f487c for key /Length
# Multiple definitions in dictionary at byte 0x14f9c63 for key /Length
# Multiple definitions in dictionary at byte 0x15019a4 for key /Length
# Multiple definitions in dictionary at byte 0x150a078 for key /Length
# Multiple definitions in dictionary at byte 0x151d1ca for key /Length
# Multiple definitions in dictionary at byte 0x15322c8 for key /Length
# Multiple definitions in dictionary at byte 0x153a993 for key /Length
# Multiple definitions in dictionary at byte 0x154eec5 for key /Length
# Multiple definitions in dictionary at byte 0x155a49e for key /Length
# Multiple definitions in dictionary at byte 0x156808e for key /Length
# Multiple definitions in dictionary at byte 0x1570673 for key /Length
# Multiple definitions in dictionary at byte 0x1577033 for key /Length
# Multiple definitions in dictionary at byte 0x158bef4 for key /Length
# Multiple definitions in dictionary at byte 0x1593a83 for key /Length
# Multiple definitions in dictionary at byte 0x15a62b7 for key /Length
# Multiple definitions in dictionary at byte 0x15adb6d for key /Length
# Multiple definitions in dictionary at byte 0x15be393 for key /Length
# Multiple definitions in dictionary at byte 0x15d83b2 for key /Length
# Multiple definitions in dictionary at byte 0x15eee7c for key /Length
# Multiple definitions in dictionary at byte 0x1606715 for key /Length
# Multiple definitions in dictionary at byte 0x1612eaa for key /Length
# Multiple definitions in dictionary at byte 0x162106e for key /Length
# Multiple definitions in dictionary at byte 0x162cc11 for key /Length
# Multiple definitions in dictionary at byte 0x163dc76 for key /Length
# Multiple definitions in dictionary at byte 0x164a282 for key /Length
# Multiple definitions in dictionary at byte 0x165c2f9 for key /Length
# Multiple definitions in dictionary at byte 0x166c6a7 for key /Length
# Multiple definitions in dictionary at byte 0x1687c3b for key /Length
# Multiple definitions in dictionary at byte 0x1698fe2 for key /Length
# Multiple definitions in dictionary at byte 0x16a7d77 for key /Length
# Multiple definitions in dictionary at byte 0x16b1d0f for key /Length
# Multiple definitions in dictionary at byte 0x16bfc86 for key /Length
# Multiple definitions in dictionary at byte 0x16da877 for key /Length
# Uploading to pinecone index langchain-quickstart
# Multiple definitions in dictionary at byte 0x1356 for key /Length
# Multiple definitions in dictionary at byte 0x5087 for key /Length
# Multiple definitions in dictionary at byte 0x6cde for key /Length
# Multiple definitions in dictionary at byte 0x12a6c for key /Length
# Multiple definitions in dictionary at byte 0x1393e for key /Length
# Multiple definitions in dictionary at byte 0x1f750 for key /Length
# Multiple definitions in dictionary at byte 0x2d129 for key /Length
# Multiple definitions in dictionary at byte 0x388e9 for key /Length
# Multiple definitions in dictionary at byte 0x3dce1 for key /Length
# Multiple definitions in dictionary at byte 0x46e35 for key /Length
# Multiple definitions in dictionary at byte 0x51401 for key /Length
# Multiple definitions in dictionary at byte 0x661fd for key /Length
# Multiple definitions in dictionary at byte 0x7b119 for key /Length
# Multiple definitions in dictionary at byte 0x894d0 for key /Length
# Multiple definitions in dictionary at byte 0x940a0 for key /Length
# Multiple definitions in dictionary at byte 0x9a4c5 for key /Length
# Multiple definitions in dictionary at byte 0xa2694 for key /Length
# Multiple definitions in dictionary at byte 0xb7d7f for key /Length
# Multiple definitions in dictionary at byte 0xcea87 for key /Length
# Multiple definitions in dictionary at byte 0xda809 for key /Length
# Multiple definitions in dictionary at byte 0xf1bb6 for key /Length
# Multiple definitions in dictionary at byte 0xfc65c for key /Length
# Multiple definitions in dictionary at byte 0x103689 for key /Length
# Multiple definitions in dictionary at byte 0x10b96e for key /Length
# Multiple definitions in dictionary at byte 0x1153ba for key /Length
# Multiple definitions in dictionary at byte 0x1264cb for key /Length
# Parsing: ../data/AMS/AMS_2001.pdf
# Multiple definitions in dictionary at byte 0x134e79 for key /Length
# Multiple definitions in dictionary at byte 0x145940 for key /Length
# Multiple definitions in dictionary at byte 0x154987 for key /Length
# Multiple definitions in dictionary at byte 0x1697a1 for key /Length
# Multiple definitions in dictionary at byte 0x17fc21 for key /Length
# Multiple definitions in dictionary at byte 0x1938ee for key /Length
# Multiple definitions in dictionary at byte 0x1a1f6c for key /Length
# Multiple definitions in dictionary at byte 0x1b1463 for key /Length
# Multiple definitions in dictionary at byte 0x1b24de for key /Length
# Multiple definitions in dictionary at byte 0x1ce265 for key /Length
# Multiple definitions in dictionary at byte 0x1e363a for key /Length
# Multiple definitions in dictionary at byte 0x1f4307 for key /Length
# Multiple definitions in dictionary at byte 0x2053c7 for key /Length
# Multiple definitions in dictionary at byte 0x219257 for key /Length
# Multiple definitions in dictionary at byte 0x225ba9 for key /Length
# Multiple definitions in dictionary at byte 0x2372d9 for key /Length
# Multiple definitions in dictionary at byte 0x25da0a for key /Length
# Multiple definitions in dictionary at byte 0x26de69 for key /Length
# Multiple definitions in dictionary at byte 0x27841e for key /Length
# Multiple definitions in dictionary at byte 0x289cb0 for key /Length
# Multiple definitions in dictionary at byte 0x2b6b35 for key /Length
# Multiple definitions in dictionary at byte 0x2c2756 for key /Length
# Multiple definitions in dictionary at byte 0x2df023 for key /Length
# Multiple definitions in dictionary at byte 0x2e5917 for key /Length
# Multiple definitions in dictionary at byte 0x2f650b for key /Length
# Multiple definitions in dictionary at byte 0x305f53 for key /Length
# Multiple definitions in dictionary at byte 0x31bf46 for key /Length
# Multiple definitions in dictionary at byte 0x334ada for key /Length
# Multiple definitions in dictionary at byte 0x34043d for key /Length
# Multiple definitions in dictionary at byte 0x3577fe for key /Length
# Multiple definitions in dictionary at byte 0x35e090 for key /Length
# Multiple definitions in dictionary at byte 0x3750d4 for key /Length
# Multiple definitions in dictionary at byte 0x3879cf for key /Length
# Multiple definitions in dictionary at byte 0x3947f2 for key /Length
# Multiple definitions in dictionary at byte 0x3a555d for key /Length
# Multiple definitions in dictionary at byte 0x3c4711 for key /Length
# Multiple definitions in dictionary at byte 0x3db747 for key /Length
# Multiple definitions in dictionary at byte 0x3f6eea for key /Length
# Multiple definitions in dictionary at byte 0x4091ce for key /Length
# Multiple definitions in dictionary at byte 0x41e05a for key /Length
# Multiple definitions in dictionary at byte 0x426447 for key /Length
# Multiple definitions in dictionary at byte 0x44088f for key /Length
# Multiple definitions in dictionary at byte 0x451814 for key /Length
# Multiple definitions in dictionary at byte 0x4605c1 for key /Length
# Multiple definitions in dictionary at byte 0x47bc3b for key /Length
# Multiple definitions in dictionary at byte 0x48b79d for key /Length
# Multiple definitions in dictionary at byte 0x4a4b9a for key /Length
# Multiple definitions in dictionary at byte 0x4b3744 for key /Length
# Multiple definitions in dictionary at byte 0x4c6879 for key /Length
# Multiple definitions in dictionary at byte 0x4e9840 for key /Length
# Multiple definitions in dictionary at byte 0x4f7df2 for key /Length
# Multiple definitions in dictionary at byte 0x50e955 for key /Length
# Multiple definitions in dictionary at byte 0x52c907 for key /Length
# Multiple definitions in dictionary at byte 0x53be9d for key /Length
# Multiple definitions in dictionary at byte 0x560a52 for key /Length
# Multiple definitions in dictionary at byte 0x57ffd7 for key /Length
# Multiple definitions in dictionary at byte 0x59502d for key /Length
# Multiple definitions in dictionary at byte 0x5a611d for key /Length
# Multiple definitions in dictionary at byte 0x5c6fd7 for key /Length
# Multiple definitions in dictionary at byte 0x5ec13b for key /Length
# Multiple definitions in dictionary at byte 0x6027a0 for key /Length
# Multiple definitions in dictionary at byte 0x61efcb for key /Length
# Multiple definitions in dictionary at byte 0x646992 for key /Length
# Multiple definitions in dictionary at byte 0x65668a for key /Length
# Multiple definitions in dictionary at byte 0x67581d for key /Length
# Multiple definitions in dictionary at byte 0x68824a for key /Length
# Multiple definitions in dictionary at byte 0x689044 for key /Length
# Multiple definitions in dictionary at byte 0x6980e6 for key /Length
# Multiple definitions in dictionary at byte 0x6b45de for key /Length
# Multiple definitions in dictionary at byte 0x6cd536 for key /Length
# Multiple definitions in dictionary at byte 0x6d975b for key /Length
# Multiple definitions in dictionary at byte 0x6e751d for key /Length
# Multiple definitions in dictionary at byte 0x6fc0a5 for key /Length
# Multiple definitions in dictionary at byte 0x712003 for key /Length
# Multiple definitions in dictionary at byte 0x72da51 for key /Length
# Multiple definitions in dictionary at byte 0x73fc6c for key /Length
# Multiple definitions in dictionary at byte 0x75b010 for key /Length
# Multiple definitions in dictionary at byte 0x771ed9 for key /Length
# Multiple definitions in dictionary at byte 0x7780ae for key /Length
# Multiple definitions in dictionary at byte 0x788891 for key /Length
# Multiple definitions in dictionary at byte 0x7a17d0 for key /Length
# Multiple definitions in dictionary at byte 0x7c5749 for key /Length
# Multiple definitions in dictionary at byte 0x7da828 for key /Length
# Multiple definitions in dictionary at byte 0x7e7de1 for key /Length
# Multiple definitions in dictionary at byte 0x7f01de for key /Length
# Multiple definitions in dictionary at byte 0x7f890b for key /Length
# Multiple definitions in dictionary at byte 0x7fe85c for key /Length
# Multiple definitions in dictionary at byte 0x805ba2 for key /Length
# Multiple definitions in dictionary at byte 0x80b4e5 for key /Length
# Multiple definitions in dictionary at byte 0x8136c7 for key /Length
# Multiple definitions in dictionary at byte 0x81be1d for key /Length
# Multiple definitions in dictionary at byte 0x822b4c for key /Length
# Multiple definitions in dictionary at byte 0x8238f8 for key /Length
# Multiple definitions in dictionary at byte 0x835de4 for key /Length
# Multiple definitions in dictionary at byte 0x840bd1 for key /Length
# Multiple definitions in dictionary at byte 0x84f5cd for key /Length
# Multiple definitions in dictionary at byte 0x859d62 for key /Length
# Multiple definitions in dictionary at byte 0x868c4b for key /Length
# Multiple definitions in dictionary at byte 0x873408 for key /Length
# Multiple definitions in dictionary at byte 0x8872d1 for key /Length
# Multiple definitions in dictionary at byte 0x89e733 for key /Length
# Multiple definitions in dictionary at byte 0x8b14a7 for key /Length
# Multiple definitions in dictionary at byte 0x8bc619 for key /Length
# Multiple definitions in dictionary at byte 0x8bfca6 for key /Length
# Multiple definitions in dictionary at byte 0x8c3ce0 for key /Length
# Multiple definitions in dictionary at byte 0x8d3690 for key /Length
# Multiple definitions in dictionary at byte 0x8dacc1 for key /Length
# Multiple definitions in dictionary at byte 0x8eac96 for key /Length
# Multiple definitions in dictionary at byte 0x8ef9c8 for key /Length
# Multiple definitions in dictionary at byte 0x8fa3f1 for key /Length
# Multiple definitions in dictionary at byte 0x8fb68e for key /Length
# Multiple definitions in dictionary at byte 0x90e326 for key /Length
# Multiple definitions in dictionary at byte 0x922957 for key /Length
# Multiple definitions in dictionary at byte 0x939f2c for key /Length
# Multiple definitions in dictionary at byte 0x9491f8 for key /Length
# Multiple definitions in dictionary at byte 0x974ff5 for key /Length
# Multiple definitions in dictionary at byte 0x97e654 for key /Length
# Multiple definitions in dictionary at byte 0x9911bb for key /Length
# Multiple definitions in dictionary at byte 0x99e1aa for key /Length
# Multiple definitions in dictionary at byte 0x9b4fea for key /Length
# Multiple definitions in dictionary at byte 0x9c8fe3 for key /Length
# Multiple definitions in dictionary at byte 0x9db60a for key /Length
# Multiple definitions in dictionary at byte 0x9e1af4 for key /Length
# Multiple definitions in dictionary at byte 0x9f519b for key /Length
# Multiple definitions in dictionary at byte 0xa08b42 for key /Length
# Multiple definitions in dictionary at byte 0xa159af for key /Length
# Multiple definitions in dictionary at byte 0xa26842 for key /Length
# Multiple definitions in dictionary at byte 0xa39c1e for key /Length
# Multiple definitions in dictionary at byte 0xa3ae6a for key /Length
# Multiple definitions in dictionary at byte 0xa4e75d for key /Length
# Multiple definitions in dictionary at byte 0xa5e6dc for key /Length
# Multiple definitions in dictionary at byte 0xa6494e for key /Length
# Multiple definitions in dictionary at byte 0xa7a2a9 for key /Length
# Multiple definitions in dictionary at byte 0xa960a8 for key /Length
# Multiple definitions in dictionary at byte 0xaa7dc3 for key /Length
# Multiple definitions in dictionary at byte 0xab3930 for key /Length
# Multiple definitions in dictionary at byte 0xac1a66 for key /Length
# Multiple definitions in dictionary at byte 0xad31c9 for key /Length
# Multiple definitions in dictionary at byte 0xaf31c1 for key /Length
# Multiple definitions in dictionary at byte 0xb01cab for key /Length
# Multiple definitions in dictionary at byte 0xb12aeb for key /Length
# Multiple definitions in dictionary at byte 0xb24f43 for key /Length
# Multiple definitions in dictionary at byte 0xb33c30 for key /Length
# Multiple definitions in dictionary at byte 0xb3d656 for key /Length
# Multiple definitions in dictionary at byte 0xb4f80f for key /Length
# Multiple definitions in dictionary at byte 0xb5e8a2 for key /Length
# Multiple definitions in dictionary at byte 0xb67e66 for key /Length
# Multiple definitions in dictionary at byte 0xb7819b for key /Length
# Multiple definitions in dictionary at byte 0xb843be for key /Length
# Multiple definitions in dictionary at byte 0xbab5fe for key /Length
# Multiple definitions in dictionary at byte 0xbbbae8 for key /Length
# Multiple definitions in dictionary at byte 0xbcbdd6 for key /Length
# Multiple definitions in dictionary at byte 0xbe5bc8 for key /Length
# Multiple definitions in dictionary at byte 0xbf4b77 for key /Length
# Multiple definitions in dictionary at byte 0xc0acb3 for key /Length
# Multiple definitions in dictionary at byte 0xc3b894 for key /Length
# Multiple definitions in dictionary at byte 0xc5818d for key /Length
# Multiple definitions in dictionary at byte 0xc62850 for key /Length
# Multiple definitions in dictionary at byte 0xc7baab for key /Length
# Multiple definitions in dictionary at byte 0xc8b762 for key /Length
# Multiple definitions in dictionary at byte 0xc9e099 for key /Length
# Multiple definitions in dictionary at byte 0xcaf919 for key /Length
# Multiple definitions in dictionary at byte 0xcb0880 for key /Length
# Multiple definitions in dictionary at byte 0xcc11fc for key /Length
# Multiple definitions in dictionary at byte 0xccbf39 for key /Length
# Multiple definitions in dictionary at byte 0xcdb89f for key /Length
# Multiple definitions in dictionary at byte 0xd14edd for key /Length
# Multiple definitions in dictionary at byte 0xd2e1b0 for key /Length
# Multiple definitions in dictionary at byte 0xd3c724 for key /Length
# Multiple definitions in dictionary at byte 0xd4b909 for key /Length
# Multiple definitions in dictionary at byte 0xd5c713 for key /Length
# Multiple definitions in dictionary at byte 0xd7e50e for key /Length
# Multiple definitions in dictionary at byte 0xd8e87d for key /Length
# Multiple definitions in dictionary at byte 0xd9f5e2 for key /Length
# Multiple definitions in dictionary at byte 0xdb60ec for key /Length
# Multiple definitions in dictionary at byte 0xdd4e8f for key /Length
# Multiple definitions in dictionary at byte 0xde368a for key /Length
# Multiple definitions in dictionary at byte 0xdf5d93 for key /Length
# Multiple definitions in dictionary at byte 0xe0c01f for key /Length
# Multiple definitions in dictionary at byte 0xe2c247 for key /Length
# Multiple definitions in dictionary at byte 0xe4b559 for key /Length
# Multiple definitions in dictionary at byte 0xe5d848 for key /Length
# Multiple definitions in dictionary at byte 0xe68cf2 for key /Length
# Multiple definitions in dictionary at byte 0xe7e6bc for key /Length
# Multiple definitions in dictionary at byte 0xe95da2 for key /Length
# Multiple definitions in dictionary at byte 0xead421 for key /Length
# Multiple definitions in dictionary at byte 0xec344f for key /Length
# Multiple definitions in dictionary at byte 0xed9c81 for key /Length
# Multiple definitions in dictionary at byte 0xeeedf0 for key /Length
# Multiple definitions in dictionary at byte 0xf070e6 for key /Length
# Multiple definitions in dictionary at byte 0xf1e7c5 for key /Length
# Multiple definitions in dictionary at byte 0xf3191f for key /Length
# Multiple definitions in dictionary at byte 0xf42f68 for key /Length
# Multiple definitions in dictionary at byte 0xf48dd3 for key /Length
# Multiple definitions in dictionary at byte 0xf4eb8e for key /Length
# Multiple definitions in dictionary at byte 0xf79f56 for key /Length
# Multiple definitions in dictionary at byte 0xf91c83 for key /Length
# Multiple definitions in dictionary at byte 0xfa583e for key /Length
# Multiple definitions in dictionary at byte 0xfb8d3c for key /Length
# Multiple definitions in dictionary at byte 0xfca13d for key /Length
# Multiple definitions in dictionary at byte 0xfdbc53 for key /Length
# Multiple definitions in dictionary at byte 0xfebcde for key /Length
# Multiple definitions in dictionary at byte 0xff4235 for key /Length
# Multiple definitions in dictionary at byte 0x100559d for key /Length
# Multiple definitions in dictionary at byte 0x10179b0 for key /Length
# Multiple definitions in dictionary at byte 0x1030b58 for key /Length
# Multiple definitions in dictionary at byte 0x103f9c3 for key /Length
# Multiple definitions in dictionary at byte 0x1051c63 for key /Length
# Multiple definitions in dictionary at byte 0x1072d83 for key /Length
# Multiple definitions in dictionary at byte 0x1089f98 for key /Length
# Multiple definitions in dictionary at byte 0x109ff37 for key /Length
# Multiple definitions in dictionary at byte 0x10b1070 for key /Length
# Multiple definitions in dictionary at byte 0x10be440 for key /Length
# Multiple definitions in dictionary at byte 0x10d4bc5 for key /Length
# Multiple definitions in dictionary at byte 0x10f0d79 for key /Length
# Multiple definitions in dictionary at byte 0x1107b14 for key /Length
# Multiple definitions in dictionary at byte 0x11104e5 for key /Length
# Multiple definitions in dictionary at byte 0x11248c6 for key /Length
# Multiple definitions in dictionary at byte 0x11350bd for key /Length
# Multiple definitions in dictionary at byte 0x11400b0 for key /Length
# Multiple definitions in dictionary at byte 0x1141353 for key /Length
# Multiple definitions in dictionary at byte 0x1153d6c for key /Length
# Multiple definitions in dictionary at byte 0x1162c1b for key /Length
# Multiple definitions in dictionary at byte 0x1168d9f for key /Length
# Multiple definitions in dictionary at byte 0x1171c20 for key /Length
# Multiple definitions in dictionary at byte 0x117bea9 for key /Length
# Multiple definitions in dictionary at byte 0x1193cb0 for key /Length
# Multiple definitions in dictionary at byte 0x11abcfd for key /Length
# Multiple definitions in dictionary at byte 0x11bffd3 for key /Length
# Multiple definitions in dictionary at byte 0x11cfee0 for key /Length
# Multiple definitions in dictionary at byte 0x11d9276 for key /Length
# Multiple definitions in dictionary at byte 0x11e9a7c for key /Length
# Multiple definitions in dictionary at byte 0x11ff5db for key /Length
# Multiple definitions in dictionary at byte 0x12086af for key /Length
# Multiple definitions in dictionary at byte 0x12092e2 for key /Length
# Multiple definitions in dictionary at byte 0x121a90a for key /Length
# Multiple definitions in dictionary at byte 0x1228e1b for key /Length
# Multiple definitions in dictionary at byte 0x123cddf for key /Length
# Multiple definitions in dictionary at byte 0x124e87a for key /Length
# Multiple definitions in dictionary at byte 0x12595f9 for key /Length
# Multiple definitions in dictionary at byte 0x1269220 for key /Length
# Multiple definitions in dictionary at byte 0x128c967 for key /Length
# Multiple definitions in dictionary at byte 0x1299957 for key /Length
# Multiple definitions in dictionary at byte 0x12b10b6 for key /Length
# Multiple definitions in dictionary at byte 0x12ca2e8 for key /Length
# Multiple definitions in dictionary at byte 0x12d8180 for key /Length
# Multiple definitions in dictionary at byte 0x12f8263 for key /Length
# Multiple definitions in dictionary at byte 0x1318aa7 for key /Length
# Multiple definitions in dictionary at byte 0x1326c7e for key /Length
# Multiple definitions in dictionary at byte 0x133ca62 for key /Length
# Multiple definitions in dictionary at byte 0x1347207 for key /Length
# Multiple definitions in dictionary at byte 0x135d28d for key /Length
# Multiple definitions in dictionary at byte 0x1374727 for key /Length
# Multiple definitions in dictionary at byte 0x137c816 for key /Length
# Multiple definitions in dictionary at byte 0x139387d for key /Length
# Multiple definitions in dictionary at byte 0x13d2654 for key /Length
# Multiple definitions in dictionary at byte 0x140a17b for key /Length
# Multiple definitions in dictionary at byte 0x1416c7a for key /Length
# Multiple definitions in dictionary at byte 0x141a1ae for key /Length
# Multiple definitions in dictionary at byte 0x142b431 for key /Length
# Multiple definitions in dictionary at byte 0x143d7a7 for key /Length
# Multiple definitions in dictionary at byte 0x1447bc8 for key /Length
# Multiple definitions in dictionary at byte 0x1455d22 for key /Length
# Multiple definitions in dictionary at byte 0x146de56 for key /Length
# Multiple definitions in dictionary at byte 0x1482932 for key /Length
# Multiple definitions in dictionary at byte 0x1490cef for key /Length
# Multiple definitions in dictionary at byte 0x14a657c for key /Length
# Multiple definitions in dictionary at byte 0x14cd6f1 for key /Length
# Multiple definitions in dictionary at byte 0x14dead4 for key /Length
# Multiple definitions in dictionary at byte 0x14f0a61 for key /Length
# Multiple definitions in dictionary at byte 0x14f4c81 for key /Length
# Multiple definitions in dictionary at byte 0x1506175 for key /Length
# Multiple definitions in dictionary at byte 0x151a19a for key /Length
# Multiple definitions in dictionary at byte 0x1533744 for key /Length
# Multiple definitions in dictionary at byte 0x155083a for key /Length
# Multiple definitions in dictionary at byte 0x1574b47 for key /Length
# Multiple definitions in dictionary at byte 0x158b3d2 for key /Length
# Multiple definitions in dictionary at byte 0x159d4d4 for key /Length
# Multiple definitions in dictionary at byte 0x15b1a48 for key /Length
# Multiple definitions in dictionary at byte 0x15c60a0 for key /Length
# Multiple definitions in dictionary at byte 0x15d61f7 for key /Length
# Multiple definitions in dictionary at byte 0x15e459c for key /Length
# Multiple definitions in dictionary at byte 0x15f6df4 for key /Length
# Multiple definitions in dictionary at byte 0x160adff for key /Length
# Multiple definitions in dictionary at byte 0x1615854 for key /Length
# Multiple definitions in dictionary at byte 0x16231ae for key /Length
# Multiple definitions in dictionary at byte 0x1623763 for key /Length
# Multiple definitions in dictionary at byte 0x1623ebf for key /Length
# Uploading to pinecone index langchain-quickstart
# Parsing: ../data/AMS/AMS_2016.pdf
# Uploading to pinecone index langchain-quickstart
# Parsing: ../data/AMS/AMS_2002.pdf
# Uploading to pinecone index langchain-quickstart
# Parsing: ../data/AMS/AMS_2018.pdf
# Uploading to pinecone index langchain-quickstart
# Parsing: ../data/AMS/AMS_2008.pdf
# Uploading to pinecone index langchain-quickstart
# Parsing: ../data/AMS/AMS_2020.pdf
# Uploading to pinecone index langchain-quickstart
